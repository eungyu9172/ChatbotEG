# %%
# LangGraph 워크플로우 시각화

이 노트북은 LangGraph 챗봇의 워크플로우를 시각화합니다.
# Out:
#   Cell In[1], line 3
#     이 노트북은 LangGraph 챗봇의 워크플로우를 시각화합니다.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
#  # 필요한 라이브러리 import
# from IPython.display import Image, display
# from app import ChatbotApplication
# import sys
# from pathlib import Path
#
# # 프로젝트 루트를 Python 경로에 추가
# project_root = Path.cwd()
# sys.path.insert(0, str(project_root))

# %%
from IPython.display import Image, display
from app import ChatbotApplication
import sys
from pathlib import Path

 # 챗봇 애플리케이션 초기화
print("🚀 챗봇 애플리케이션 초기화 중...")
app = ChatbotApplication(debug_mode=False)
print("✅ 초기화 완료")
# Out:
# 2025-10-31 10:23:59,938 - utils.logger - ERROR - ❌ MCP 도구 로드 실패: This event loop is already running
# 2025-10-31 10:23:59,939 - utils.logger - INFO - 도구 없이 LLM을 사용합니다.
# /mnt/c/Users/inno/Desktop/inno_이은규/00.업무/06.GitLab/03.LangGraph/langgraph/chatbot/utils/llm_clients.py:34: RuntimeWarning: coroutine 'get_mcp_manager' was never awaited
#   AVAILABLE_TOOLS = _load_mcp_tools()
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2025-10-31 10:24:00,178 - utils.logger - WARNING - ⚠️  Bind Tools: 도구 없음
# 2025-10-31 10:24:00,213 - utils.logger - INFO - === 챗봇 세션 시작 ===
# 2025-10-31 10:24:00,214 - utils.logger - INFO - 세션 ID: 20251031_102400
# 2025-10-31 10:24:00,215 - utils.logger - INFO - 로그 파일: logs/chatbot_session_20251031_102400.txt
# 2025-10-31 10:24:00,216 - utils.logger - INFO - 🚀 ChatBot Application 초기화 시작
# 2025-10-31 10:24:00,216 - utils.logger - INFO - 디버그 모드: OFF
# 2025-10-31 10:24:00,217 - utils.logger - INFO - 사용 가능한 도구: []
# 2025-10-31 10:24:00,221 - utils.logger - INFO - ✅ 환경 설정 검증 완료
# 2025-10-31 10:24:00,223 - utils.logger - INFO - 📊 워크플로우 생성 시작
# 2025-10-31 10:24:00,225 - utils.logger - DEBUG - 노드 추가: validate_input
# 2025-10-31 10:24:00,226 - utils.logger - DEBUG - 노드 추가: rewrite
# 2025-10-31 10:24:00,226 - utils.logger - DEBUG - 노드 추가: check_simple
# 2025-10-31 10:24:00,228 - utils.logger - DEBUG - 노드 추가: direct_answer
# 2025-10-31 10:24:00,229 - utils.logger - DEBUG - 노드 추가: generate
# 2025-10-31 10:24:00,230 - utils.logger - DEBUG - 노드 추가: tools
# 2025-10-31 10:24:00,231 - utils.logger - DEBUG - 노드 추가: force_final_answer
# 2025-10-31 10:24:00,233 - utils.logger - DEBUG - 라우팅 설정 완료
# 2025-10-31 10:24:00,268 - utils.logger - INFO - ✅ 워크플로우 생성 완료
# 🚀 챗봇 애플리케이션 초기화 중...
# ✅ 초기화 완료

# %%
 # Mermaid PNG 이미지 생성 및 표시
print("🎨 Mermaid 이미지 생성 중...")
subgraph_image = app.app.get_graph().draw_mermaid_png()
print("✅ 이미지 생성 완료")

# 이미지 표시
display(Image(subgraph_image))
# Out:
# 🎨 Mermaid 이미지 생성 중...
# ✅ 이미지 생성 완료
